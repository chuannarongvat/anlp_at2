# %%
from newsapi import NewsApiClient
import requests
from bs4 import BeautifulSoup
import newspaper
import pandas as pd

# %% [markdown]
# ## API Key

# %%
api_key = 'ac0ce799defe4fbf8b412b75884ab6ca'

country = 'us'

# %%
url = f'https://newsapi.org/v2/top-headlines?country={country}&apiKey={api_key}'

# %%
response = requests.get(url)

# %%
if response.status_code == 200:
    news_data = response.json()
    news_df = pd.DataFrame(columns=['title', 'description', 'url', 'article_text'])

    for article in news_data['articles']:
        title = article['title']
        description = article['description']
        url = article['url']

        try:
            article_text = newspaper.Article(url)
            article_text.download()
            article_text.parse()
            article_text = article_text.text
        except:
            print(f"Failed to download article from {url}")
            continue

        news_df = news_df.append({'title': title, 'description': description, 'url': url, 'article_text': article_text}, ignore_index=True)
# Out:
# /var/folders/lk/qbgh0syd1l7_7h6ghvq233nr0000gn/T/ipykernel_29119/1438331631.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   news_df = news_df.append({'title': title, 'description': description, 'url': url, 'article_text': article_text}, ignore_index=True)
# /var/folders/lk/qbgh0syd1l7_7h6ghvq233nr0000gn/T/ipykernel_29119/1438331631.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   news_df = news_df.append({'title': title, 'description': description, 'url': url, 'article_text': article_text}, ignore_index=True)
# /var/folders/lk/qbgh0syd1l7_7h6ghvq233nr0000gn/T/ipykernel_29119/1438331631.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
pd.set_option('display.max_colwidth', None)

news_df
# Out:
#                                                                                                                       title  \
# 0                         Biden set to discuss wrongfully detained Americans during White House Correspondents Dinner - CNN
# 1   2023 NFL Draft seventh-round grades: Max Duggan pick a 'C+' for Chargers; Rams get 'A-' for Mr. Irrelevant - CBS Sports
# 2                                                    Yankees mull placing Judge on injured list with mild hip strain - ESPN
# 3                           California man found guilty of murdering teens who ding-dong ditched his house - New York Post
# 4                                           Lions pick WR Antoine Green in 7th round of NFL draft 2023 - Detroit Free Press
# 5                                             Russia blames Ukraine drone attack for major Crimea fuel depot fire - Reuters
# ...
